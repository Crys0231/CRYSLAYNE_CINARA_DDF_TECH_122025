# %%
# Teste de conexão com o banco de dados PostgreSQL

from sqlalchemy import create_engine
from sqlalchemy.exc import OperationalError
from sqlalchemy import text

DB_USER = "cryslayne"
DB_PASSWORD = "crys0231"
DB_HOST = "db-data-dadosfera.c9e0k2cgao73.sa-east-1.rds.amazonaws.com"
DB_PORT = "5432"
DB_NAME = "postgres"

DATABASE_URL = (
    f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}"
    f"@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

try:
    engine = create_engine(DATABASE_URL)
    with engine.connect() as conn:
        result = conn.execute(text("SELECT current_database(), version();"))
        print("Conexão bem-sucedida!")
        print(result.fetchone())
except OperationalError as e:
    print("Erro de conexão:")
    print(e)
# Out:
# Conexão bem-sucedida!
# ('postgres', 'PostgreSQL 17.6 on aarch64-unknown-linux-gnu, compiled by gcc (GCC) 12.4.0, 64-bit')

# %%
import sys
from datetime import datetime
import pandas as pd
import json

print("="*80)
print("DATA TRANSFORMATION - CAMADA TRUSTED")
print("="*80)
print(f"\nIniciado em: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Ambiente: {sys.platform}")
print(f"Python: {sys.version.split()}")
# Out:
# ================================================================================
# DATA TRANSFORMATION - CAMADA TRUSTED
# ================================================================================
#
# Iniciado em: 2026-01-21 21:29:18
# Ambiente: win32
# Python: ['3.14.0', '(tags/v3.14.0:ebf955d,', 'Oct', '7', '2025,', '10:15:03)', '[MSC', 'v.1944', '64', 'bit', '(AMD64)]']

# %%
# ===== CARREGAR DADOS RAW =====
print("\n" + "="*80)
print("CARREGANDO DADOS RAW")
print("="*80)

customers_raw = '../data/raw/customers_raw.csv'
products_raw = '../data/raw/products_raw.json'
sales_raw = '../data/raw/sales_raw.csv'

try:
    customers_raw = pd.read_csv(customers_raw)
    print(f"customers_raw: {len(customers_raw):,} registros carregados")
except FileNotFoundError:
    print(f"Arquivo não encontrado: {customers_raw}")
    customers_raw = None

try:
    with open(products_raw, 'r') as f:
        products_raw = pd.DataFrame(json.load(f))
    print(f"products_raw: {len(products_raw):,} registros carregados")
except FileNotFoundError:
    print(f"Arquivo não encontrado: {products_raw}")
    products_raw = None

try:
    sales_raw = pd.read_csv(sales_raw)
    print(f"sales_raw: {len(sales_raw):,} registros carregados")
except FileNotFoundError:
    print(f"Arquivo não encontrado: {sales_raw}")
    sales_raw = None
# Out:
# ================================================================================
# CARREGANDO DADOS RAW
# ================================================================================
# customers_raw: 5,000 registros carregados
# products_raw: 10,000 registros carregados
# sales_raw: 120,000 registros carregados

# %%
# ===== TRANSFORMAÇÃO: PRODUCTS =====
print("\n" + "="*80)
print("TRANSFORMAÇÃO: PRODUCTS_RAW → PRODUCTS_TRUSTED")
print("="*80)


products_trusted = products_raw.copy()

# Tipo de dados
products_trusted['load_capacity'] = pd.to_numeric(products_trusted['load_capacity'], errors='coerce')
products_trusted['max_speed'] = pd.to_numeric(products_trusted['max_speed'], errors='coerce')
products_trusted['temperature_limit'] = pd.to_numeric(products_trusted['temperature_limit'], errors='coerce')
products_trusted['unit_cost'] = pd.to_numeric(products_trusted['unit_cost'], errors='coerce')
products_trusted['list_price'] = pd.to_numeric(products_trusted['list_price'], errors='coerce')

print("\n-  Tipos de dados padronizados")

# FIX CRÍTICO: Margem de lucro negativa
problematic_count = (products_trusted['unit_cost'] >= products_trusted['list_price']).sum()
print(f"\n-  Detectados {problematic_count} produtos com margem negativa")

# Corrigir: set list_price = unit_cost * 1.25 (margem mínima 25%)
products_trusted.loc[
    products_trusted['unit_cost'] >= products_trusted['list_price'],
    'list_price'
] = products_trusted.loc[
    products_trusted['unit_cost'] >= products_trusted['list_price'],
    'unit_cost'
] * 1.25

print(f"Corrigidos com margem mínima de 25%")

# Adicionar campo de descrição técnica
def generate_technical_description(row):
    return f"""{row['product_name']} é um rolamento do tipo {row['bearing_type']} em {row['material']}, fabricado pela {row['manufacturer']} (modelo {row['model']}). 
    Capacidade de carga: {row['load_capacity']:.0f}N, velocidade máxima: {row['max_speed']:,.0f} RPM, 
    limite de temperatura: {row['temperature_limit']}°C. 
    Indicado para resolver problemas de {row['problem_type']}. 
    Preço: R$ {row['list_price']:.2f}, custo: R$ {row['unit_cost']:.2f}."""

products_trusted['technical_description'] = products_trusted.apply(
    generate_technical_description, axis=1
)

print("- Campo technical_description adicionado")


# Extrair features técnicas como TAGS categóricas para ML
def extract_technical_features(row):

    features = []
    
    # Tipo de rolamento
    features.append(f"tipo_{row['bearing_type'].lower().replace(' ', '_')}")
    
    # Material
    features.append(f"material_{row['material'].lower().replace(' ', '_')}")
    
    # Categoria de carga
    if row['load_capacity'] < 10000:
        features.append("carga_leve")
    elif row['load_capacity'] < 30000:
        features.append("carga_media")
    else:
        features.append("carga_pesada")
    
    # Categoria de velocidade
    if row['max_speed'] < 5000:
        features.append("velocidade_baixa")
    elif row['max_speed'] < 10000:
        features.append("velocidade_media")
    else:
        features.append("velocidade_alta")
    
    # Resistência a temperatura
    if row['temperature_limit'] < 120:
        features.append("temp_padrao")
    elif row['temperature_limit'] < 180:
        features.append("temp_elevada")
    else:
        features.append("temp_extrema")
    
    # Problema que resolve
    features.append(f"resolve_{row['problem_type'].lower().replace(' ', '_')}")
    
    return features

products_trusted['technical_features'] = products_trusted.apply(extract_technical_features, axis=1)

print("Features técnicas (tags) extraídas")
print(f"\nExemplo: {products_trusted.iloc[0]['technical_features']}")


# Esse campo será usado para gerar embeddings (na Fase 5)
products_trusted['llm_product_description'] = products_trusted['technical_description']

print("Campo llm_product_description criado a partir de technical_description")
print(f"\nExemplo:\n{products_trusted.iloc[0]['llm_product_description'][:200]}...")


# ===== VALIDAÇÕES =====
# Validar
assert (products_trusted['unit_cost'] < products_trusted['list_price']).all(), \
    "Ainda existem produtos com unit_cost >= list_price!"

assert products_trusted.isnull().sum().sum() == 0, \
    "Existem valores nulos!"

print("- Validações passaram")
# Out:
# ================================================================================
# TRANSFORMAÇÃO: PRODUCTS_RAW → PRODUCTS_TRUSTED
# ================================================================================
#
# -  Tipos de dados padronizados
#
# -  Detectados 359 produtos com margem negativa
# Corrigidos com margem mínima de 25%
# - Campo technical_description adicionado
# Features técnicas (tags) extraídas
#
# Exemplo: ['tipo_autocompensador', 'material_aço', 'carga_media', 'velocidade_alta', 'temp_padrao', 'resolve_vibração']
# Campo llm_product_description criado a partir de technical_description
#
# Exemplo:
# Rolamento Industrial 1 é um rolamento do tipo Autocompensador em Aço, fabricado pela SKF (modelo MD-859).
#     Capacidade de carga: 11549N, velocidade máxima: 13,066 RPM,
#     limite de temperatura: 1...
# - Validações passaram

# %%
# ===== TRANSFORMAÇÃO: CUSTOMERS =====
print("\n" + "="*80)
print("TRANSFORMAÇÃO: CUSTOMERS_RAW → CUSTOMERS_TRUSTED")
print("="*80)

customers_trusted = customers_raw.copy()

# Parse data columns
customers_trusted['relationship_start_date'] = pd.to_datetime(customers_trusted['relationship_start_date'])
customers_trusted['last_updated'] = pd.to_datetime(customers_trusted['last_updated'])

# Numeric types
customers_trusted['annual_revenue_estimated'] = pd.to_numeric(
    customers_trusted['annual_revenue_estimated'], errors='coerce'
)
customers_trusted['maintenance_budget_annual'] = pd.to_numeric(
    customers_trusted['maintenance_budget_annual'], errors='coerce'
)
customers_trusted['downtime_cost_per_hour'] = pd.to_numeric(
    customers_trusted['downtime_cost_per_hour'], errors='coerce'
)

# Coluna adicionada a fim de resolver issue nos testes de qualidade de dados
customers_trusted['country'] = 'Brasil'  # valor padrão para o dataset

print("- Tipos de dados padronizados")

# Mapeamento de indústria para problemas esperados
industry_problems = {
    'Mineração': ['Vibração', 'Desgaste'],
    'Siderurgia': ['Superaquecimento', 'Vibração'],
    'Alimentos': ['Contaminação', 'Desgaste'],
    'Automotiva': ['Vibração', 'Superaquecimento'],
    'Papel e Celulose': ['Desgaste', 'Contaminação'],
    'Química': ['Contaminação', 'Superaquecimento'],
    'Cimento': ['Desgaste', 'Vibração'],
    'Energia': ['Superaquecimento', 'Vibração'],
}

# Mapeia indústria → lista de problemas
customers_trusted['expected_problems'] = customers_trusted['industry'].map(industry_problems)

print("- Mapeamento de problemas esperados por indústria")

# Problema padrão se a indústria não estiver no dicionário ou estiver nula
default_problems = ['Vibração', 'Desgaste']

def fix_expected_problems(val):
    if isinstance(val, list) and len(val) > 0:
        return val
    return default_problems

customers_trusted['expected_problems'] = customers_trusted['expected_problems'].apply(
    fix_expected_problems
)

assert customers_trusted.isnull().sum().sum() == 0, "Existem valores nulos!"

# Garantir que expected_problems é sempre uma lista
def normalize_expected_problems(val):
    """Normaliza expected_problems para sempre retornar uma lista"""
    if isinstance(val, list):
        return val
    elif isinstance(val, str):
        try:
            import ast
            return ast.literal_eval(val)
        except:
            # Se for string simples, encapsular em lista
            return [val] if val else ['Uso Geral']
    else:
        return ['Uso Geral']

# Aplicar normalização
customers_trusted['expected_problems'] = customers_trusted['expected_problems'].apply(
    normalize_expected_problems
)

print("- Validações passaram")
# Out:
# ================================================================================
# TRANSFORMAÇÃO: CUSTOMERS_RAW → CUSTOMERS_TRUSTED
# ================================================================================
# - Tipos de dados padronizados
# - Mapeamento de problemas esperados por indústria
# - Validações passaram

# %%
# ===== TRANSFORMAÇÃO: SALES =====
print("\n" + "="*80)
print("TRANSFORMAÇÃO: SALES_RAW → SALES_TRUSTED")
print("="*80)

sales_trusted = sales_raw.copy()

# Parse dates
sales_trusted['sale_date'] = pd.to_datetime(sales_trusted['sale_date'])
sales_trusted['last_updated'] = pd.to_datetime(sales_trusted['last_updated'])

# Numeric types
sales_trusted['quantity'] = pd.to_numeric(sales_trusted['quantity'], errors='coerce').astype('int64')
sales_trusted['unit_price'] = pd.to_numeric(sales_trusted['unit_price'], errors='coerce')
sales_trusted['total_price'] = pd.to_numeric(sales_trusted['total_price'], errors='coerce')


# Agrupamento cumulativo por cliente (rastreia ordem de compra)
# Coluna adicionada para resolver issue nos testes de qualidade de dados
sales_trusted['subsession'] = sales_trusted.groupby('customer_id').cumcount() + 1

print("- Tipos de dados padronizados")

# Validar cálculo de total_price
tolerance = 0.01
mismatches = (
    abs(sales_trusted['total_price'] - (sales_trusted['quantity'] * sales_trusted['unit_price'])) 
    > tolerance
).sum()

if mismatches > 0:
    print(f"!  {mismatches} registros com total_price inconsistente")
    # Corrigir
    sales_trusted['total_price'] = sales_trusted['quantity'] * sales_trusted['unit_price']
    print(f"- Corrigidos")
else:
    print("- Total_price validado (100% correto)")

assert sales_trusted.isnull().sum().sum() == 0, "Existem valores nulos!"

print("- Validações passaram")
# Out:
# ================================================================================
# TRANSFORMAÇÃO: SALES_RAW → SALES_TRUSTED
# ================================================================================
# - Tipos de dados padronizados
# - Total_price validado (100% correto)
# - Validações passaram

# %%
# ===== SALVAR TRUSTED LAYER =====
print("\n" + "="*80)
print("SALVANDO TRUSTED LAYER")
print("="*80)

import os
os.makedirs('../data/trusted', exist_ok=True)

products_trusted.to_parquet('../data/trusted/products_trusted.parquet', index=False)
customers_trusted.to_parquet('../data/trusted/customers_trusted.parquet', index=False)
sales_trusted.to_parquet('../data/trusted/sales_trusted.parquet', index=False)

print("products_trusted.parquet")
print("customers_trusted.parquet")
print("sales_trusted.parquet")
# Out:
# ================================================================================
# SALVANDO TRUSTED LAYER
# ================================================================================
# products_trusted.parquet
# customers_trusted.parquet
# sales_trusted.parquet

# %%
import pandas as pd  # Adicionado import do pandas
from sqlalchemy import create_engine, text
import os

print("="*80)
print("CARREGANDO DADOS NO POSTGRESQL RDS")
print("="*80)

# Configurações do Banco
DB_USER = "cryslayne"
DB_PASSWORD = "crys0231" 
DB_HOST = "db-data-dadosfera.c9e0k2cgao73.sa-east-1.rds.amazonaws.com"
DB_PORT = "5432"
DB_NAME = "postgres"

# Caminhos dos Arquivos
PRODUCTS_FILE = '../data/trusted/products_trusted.parquet'
CUSTOMERS_FILE = '../data/trusted/customers_trusted.parquet'
SALES_FILE = '../data/trusted/sales_trusted.parquet'

print("\nVerificando arquivos...")
arquivos_existem = True
for f in [PRODUCTS_FILE, CUSTOMERS_FILE, SALES_FILE]:
    if os.path.exists(f):
        size = os.path.getsize(f) / 1024 / 1024  # MB
        print(f"{f} ({size:.2f} MB)")
    else:
        print(f"{f} NÃO ENCONTRADO!")
        arquivos_existem = False

if not arquivos_existem:
    print("Erro: Um ou mais arquivos não foram encontrados.")
    exit()

# ===== CONECTAR AO POSTGRESQL =====
print("\nConectando ao PostgreSQL RDS...")

try:
    # URL de conexão
    db_url = f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
    engine = create_engine(db_url)
    
    with engine.connect() as conn:
        conn.execute(text("SELECT 1"))
    
    print(f"Conectado ao RDS")
except Exception as e:
    print(f"Erro na conexão: {e}")
    exit()

# ===== CARREGAR ARQUIVOS PARQUET =====
print("\nCarregando dados (Lendo Parquet)...")

try:
    # CORREÇÃO PRINCIPAL: Usando read_parquet para todos os arquivos
    products_df = pd.read_parquet(PRODUCTS_FILE)
    print(f"Products: {len(products_df):,} linhas")
    
    customers_df = pd.read_parquet(CUSTOMERS_FILE)
    print(f"Customers: {len(customers_df):,} linhas")
    
    sales_df = pd.read_parquet(SALES_FILE)
    print(f"Sales: {len(sales_df):,} linhas")
    
except Exception as e:
    print(f"Erro ao ler arquivos Parquet: {e}")
    # Dica de debug: verifique se instalou pyarrow (pip install pyarrow)
    exit()

# ===== INSERIR NO BANCO =====
print("\nInserindo no PostgreSQL...")

try:
    # Limpar tabelas antigas para garantir integridade
    with engine.connect() as conn:
        print("Limpando tabelas antigas...")
        conn.execute(text("DROP TABLE IF EXISTS sales_raw CASCADE;"))
        conn.execute(text("DROP TABLE IF EXISTS products_raw CASCADE;"))
        conn.execute(text("DROP TABLE IF EXISTS customers_raw CASCADE;"))
        conn.commit()
    
    # Inserção com chunksize para performance em grandes volumes
    print("Inserindo products_raw...")
    products_df.to_sql('products_raw', engine, if_exists='replace', index=False, chunksize=1000)
    
    print("Inserindo customers_raw...")
    customers_df.to_sql('customers_raw', engine, if_exists='replace', index=False, chunksize=1000)
    
    print("Inserindo sales_raw...")
    sales_df.to_sql('sales_raw', engine, if_exists='replace', index=False, chunksize=1000)
    
    print("Tabelas inseridas com sucesso")
    
except Exception as e:
    print(f"Erro ao inserir no banco: {e}")
    exit()

# ===== CRIAR ÍNDICES =====
print("\nCriando índices...")

try:
    with engine.connect() as conn:
        # Adicionado verificação de erro para cada índice individualmente (opcional, mas recomendado)
        conn.execute(text("CREATE INDEX IF NOT EXISTS idx_products_id ON products_raw(product_id);"))
        conn.execute(text("CREATE INDEX IF NOT EXISTS idx_customers_id ON customers_raw(customer_id);"))
        conn.execute(text("CREATE INDEX IF NOT EXISTS idx_sales_id ON sales_raw(sale_id);"))
        conn.execute(text("CREATE INDEX IF NOT EXISTS idx_sales_customer ON sales_raw(customer_id);"))
        conn.execute(text("CREATE INDEX IF NOT EXISTS idx_sales_product ON sales_raw(product_id);"))
        conn.commit()
    
    print("Índices criados/verificados")
except Exception as e:
    print(f"Aviso ao criar índices (pode ser ignorado se já existirem): {e}")

# ===== VERIFICAR =====
print("\nResumo dos Dados no PostgreSQL:")

try:
    with engine.connect() as conn:
        r1 = conn.execute(text("SELECT COUNT(*) FROM products_raw;")).scalar()
        r2 = conn.execute(text("SELECT COUNT(*) FROM customers_raw;")).scalar()
        r3 = conn.execute(text("SELECT COUNT(*) FROM sales_raw;")).scalar()

    print(f"  • products_raw: {r1:,} registros")
    print(f"  • customers_raw: {r2:,} registros")
    print(f"  • sales_raw: {r3:,} registros")

except Exception as e:
    print(f"Erro ao verificar contagens: {e}")

print("\n" + "="*80)
print("CARREGAMENTO CONCLUÍDO!")
print("="*80)
# Out:
# ================================================================================
# CARREGANDO DADOS NO POSTGRESQL RDS
# ================================================================================
#
# Verificando arquivos...
# ../data/trusted/products_trusted.parquet (1.57 MB)
# ../data/trusted/customers_trusted.parquet (0.27 MB)
# ../data/trusted/sales_trusted.parquet (4.26 MB)
#
# Conectando ao PostgreSQL RDS...
# Conectado ao RDS
#
# Carregando dados (Lendo Parquet)...
# Products: 10,000 linhas
# Customers: 5,000 linhas
# Sales: 120,000 linhas
#
# Inserindo no PostgreSQL...
# Limpando tabelas antigas...
# Inserindo products_raw...
# Erro ao inserir no banco: (psycopg2.ProgrammingError) can't adapt type 'numpy.ndarray'
# [SQL: INSERT INTO products_raw (product_id, product_name, product_category, product_subcategory, manufacturer, model, bearing_type, material, load_capacity, max_speed, temperature_limit, problem_type, unit_cost, list_price, technical_description, technical ... 413071 characters truncated ... 99)s, %(technical_description__999)s, %(technical_features__999)s, %(llm_product_description__999)s)]
# [parameters: {'product_id__0': 'P00001', 'material__0': 'Aço', 'max_speed__0': 13066, 'problem_type__0': 'Vibração', 'temperature_limit__0': 106, 'technical_description__0': 'Rolamento Industrial 1 é um rolamento do tipo Autocompensador em Aço, fabricado pela SKF (modelo MD-859). \n    Capacidade de carga: 11549N, velocida ... (3 characters truncated) ... máxima: 13,066 RPM, \n    limite de temperatura: 106°C. \n    Indicado para resolver problemas de Vibração. \n    Preço: R$ 394.65, custo: R$ 315.72.', 'product_subcategory__0': 'Esférico', 'load_capacity__0': 11548.93, 'list_price__0': 394.65000000000003, 'model__0': 'MD-859', 'unit_cost__0': 315.72, 'technical_features__0': array(['tipo_autocompensador', 'material_aço', 'carga_media',
#        'velocidade_alta', 'temp_padrao', 'resolve_vibração'], dtype=object), 'product_name__0': 'Rolamento Industrial 1', 'product_category__0': 'Componentes Mecânicos', 'llm_product_description__0': 'Rolamento Industrial 1 é um rolamento do tipo Autocompensador em Aço, fabricado pela SKF (modelo MD-859). \n    Capacidade de carga: 11549N, velocida ... (3 characters truncated) ... máxima: 13,066 RPM, \n    limite de temperatura: 106°C. \n    Indicado para resolver problemas de Vibração. \n    Preço: R$ 394.65, custo: R$ 315.72.', 'bearing_type__0': 'Autocompensador', 'manufacturer__0': 'SKF', 'product_id__1': 'P00002', 'material__1': 'Aço', 'max_speed__1': 12731, 'problem_type__1': 'Contaminação', 'temperature_limit__1': 246, 'technical_description__1': 'Rolamento Industrial 2 é um rolamento do tipo Contato Angular em Aço, fabricado pela NSK (modelo MD-617). \n    Capacidade de carga: 28282N, velocida ... (8 characters truncated) ... a: 12,731 RPM, \n    limite de temperatura: 246°C. \n    Indicado para resolver problemas de Contaminação. \n    Preço: R$ 1849.94, custo: R$ 149.20.', 'product_subcategory__1': 'Cilíndrico', 'load_capacity__1': 28281.63, 'list_price__1': 1849.94, 'model__1': 'MD-617', 'unit_cost__1': 149.2, 'technical_features__1': array(['tipo_contato_angular', 'material_aço', 'carga_media',
#        'velocidade_alta', 'temp_extrema', 'resolve_contaminação'],
#       dtype=object), 'product_name__1': 'Rolamento Industrial 2', 'product_category__1': 'Rolamentos', 'llm_product_description__1': 'Rolamento Industrial 2 é um rolamento do tipo Contato Angular em Aço, fabricado pela NSK (modelo MD-617). \n    Capacidade de carga: 28282N, velocida ... (8 characters truncated) ... a: 12,731 RPM, \n    limite de temperatura: 246°C. \n    Indicado para resolver problemas de Contaminação. \n    Preço: R$ 1849.94, custo: R$ 149.20.', 'bearing_type__1': 'Contato Angular', 'manufacturer__1': 'NSK', 'product_id__2': 'P00003', 'material__2': 'Aço', 'max_speed__2': 13509, 'problem_type__2': 'Vibração', 'temperature_limit__2': 166, 'technical_description__2': 'Rolamento Industrial 3 é um rolamento do tipo Autocompensador em Aço, fabricado pela Timken (modelo MD-448). \n    Capacidade de carga: 11158N, veloc ... (5 characters truncated) ...  máxima: 13,509 RPM, \n    limite de temperatura: 166°C. \n    Indicado para resolver problemas de Vibração. \n    Preço: R$ 470.81, custo: R$ 91.74.', 'product_subcategory__2': 'Cilíndrico', 'load_capacity__2': 11158.03, 'list_price__2': 470.81, 'model__2': 'MD-448', 'unit_cost__2': 91.74, 'technical_features__2': array(['tipo_autocompensador', 'material_aço', 'carga_media',
#        'velocidade_alta', 'temp_elevada', 'resolve_vibração'],
#       dtype=object), 'product_name__2': 'Rolamento Industrial 3', 'product_category__2': 'Rolamentos', 'llm_product_description__2': 'Rolamento Industrial 3 é um rolamento do tipo Autocompensador em Aço, fabricado pela Timken (modelo MD-448). \n    Capacidade de carga: 11158N, veloc ... (5 characters truncated) ...  máxima: 13,509 RPM, \n    limite de temperatura: 166°C. \n    Indicado para resolver problemas de Vibração. \n    Preço: R$ 470.81, custo: R$ 91.74.', 'bearing_type__2': 'Autocompensador' ... 16900 parameters truncated ... 'material__997': 'Cerâmica', 'max_speed__997': 1159, 'problem_type__997': 'Desgaste', 'temperature_limit__997': 232, 'technical_description__997': 'Rolamento Industrial 998 é um rolamento do tipo Cilíndrico em Cerâmica, fabricado pela FAG (modelo MD-178). \n    Capacidade de carga: 38133N, veloci ... (5 characters truncated) ... máxima: 1,159 RPM, \n    limite de temperatura: 232°C. \n    Indicado para resolver problemas de Desgaste. \n    Preço: R$ 1832.84, custo: R$ 486.29.', 'product_subcategory__997': 'Cilíndrico', 'load_capacity__997': 38132.91, 'list_price__997': 1832.84, 'model__997': 'MD-178', 'unit_cost__997': 486.29, 'technical_features__997': array(['tipo_cilíndrico', 'material_cerâmica', 'carga_pesada',
#        'velocidade_baixa', 'temp_extrema', 'resolve_desgaste'],
#       dtype=object), 'product_name__997': 'Rolamento Industrial 998', 'product_category__997': 'Rolamentos', 'llm_product_description__997': 'Rolamento Industrial 998 é um rolamento do tipo Cilíndrico em Cerâmica, fabricado pela FAG (modelo MD-178). \n    Capacidade de carga: 38133N, veloci ... (5 characters truncated) ... máxima: 1,159 RPM, \n    limite de temperatura: 232°C. \n    Indicado para resolver problemas de Desgaste. \n    Preço: R$ 1832.84, custo: R$ 486.29.', 'bearing_type__997': 'Cilíndrico', 'manufacturer__997': 'FAG', 'product_id__998': 'P00999', 'material__998': 'Aço', 'max_speed__998': 5762, 'problem_type__998': 'Superaquecimento', 'temperature_limit__998': 138, 'technical_description__998': 'Rolamento Industrial 999 é um rolamento do tipo Esférico em Aço, fabricado pela Timken (modelo MD-212). \n    Capacidade de carga: 28580N, velocidade ... (9 characters truncated) ... 5,762 RPM, \n    limite de temperatura: 138°C. \n    Indicado para resolver problemas de Superaquecimento. \n    Preço: R$ 2370.72, custo: R$ 389.75.', 'product_subcategory__998': 'Cilíndrico', 'load_capacity__998': 28579.7, 'list_price__998': 2370.72, 'model__998': 'MD-212', 'unit_cost__998': 389.75, 'technical_features__998': array(['tipo_esférico', 'material_aço', 'carga_media', 'velocidade_media',
#        'temp_elevada', 'resolve_superaquecimento'], dtype=object), 'product_name__998': 'Rolamento Industrial 999', 'product_category__998': 'Mancais', 'llm_product_description__998': 'Rolamento Industrial 999 é um rolamento do tipo Esférico em Aço, fabricado pela Timken (modelo MD-212). \n    Capacidade de carga: 28580N, velocidade ... (9 characters truncated) ... 5,762 RPM, \n    limite de temperatura: 138°C. \n    Indicado para resolver problemas de Superaquecimento. \n    Preço: R$ 2370.72, custo: R$ 389.75.', 'bearing_type__998': 'Esférico', 'manufacturer__998': 'Timken', 'product_id__999': 'P01000', 'material__999': 'Cerâmica', 'max_speed__999': 9940, 'problem_type__999': 'Contaminação', 'temperature_limit__999': 145, 'technical_description__999': 'Rolamento Industrial 1000 é um rolamento do tipo Agujas em Cerâmica, fabricado pela FAG (modelo MD-563). \n    Capacidade de carga: 17864N, velocidad ... (6 characters truncated) ... ma: 9,940 RPM, \n    limite de temperatura: 145°C. \n    Indicado para resolver problemas de Contaminação. \n    Preço: R$ 1484.50, custo: R$ 164.09.', 'product_subcategory__999': 'Autocompensador', 'load_capacity__999': 17863.66, 'list_price__999': 1484.5, 'model__999': 'MD-563', 'unit_cost__999': 164.09, 'technical_features__999': array(['tipo_agujas', 'material_cerâmica', 'carga_media',
#        'velocidade_media', 'temp_elevada', 'resolve_contaminação'],
#       dtype=object), 'product_name__999': 'Rolamento Industrial 1000', 'product_category__999': 'Rolamentos', 'llm_product_description__999': 'Rolamento Industrial 1000 é um rolamento do tipo Agujas em Cerâmica, fabricado pela FAG (modelo MD-563). \n    Capacidade de carga: 17864N, velocidad ... (6 characters truncated) ... ma: 9,940 RPM, \n    limite de temperatura: 145°C. \n    Indicado para resolver problemas de Contaminação. \n    Preço: R$ 1484.50, custo: R$ 164.09.', 'bearing_type__999': 'Agujas', 'manufacturer__999': 'FAG'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# Criando índices...
# Aviso ao criar índices (pode ser ignorado se já existirem): (psycopg2.errors.UndefinedTable) relation "customers_raw" does not exist
#
# [SQL: CREATE INDEX IF NOT EXISTS idx_customers_id ON customers_raw(customer_id);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# Resumo dos Dados no PostgreSQL:
# Erro ao verificar contagens: (psycopg2.errors.UndefinedTable) relation "customers_raw" does not exist
# LINE 1: SELECT COUNT(*) FROM customers_raw;
#                              ^
#
# [SQL: SELECT COUNT(*) FROM customers_raw;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# ================================================================================
# CARREGAMENTO CONCLUÍDO!
# ================================================================================

# %%
# ===== RELATÓRIO FINAL =====
print("\n" + "="*80)
print("RELATÓRIO FINAL - PHASE 2")
print("="*80)

print(f"""
RESUMO DAS TRANSFORMAÇÕES:

Products:
  • Registros: {len(products_trusted):,}
  • Campos: {len(products_trusted.columns)}
  • Nulos: {products_trusted.isnull().sum().sum()}
  • Margens corrigidas: {problematic_count}
  • Descrições técnicas: Adicionadas

Customers:
  • Registros: {len(customers_trusted):,}
  • Campos: {len(customers_trusted.columns)}
  • Nulos: {customers_trusted.isnull().sum().sum()}
  • Mapeamento de problemas por indústria: Adicionado

Sales:
  • Registros: {len(sales_trusted):,}
  • Campos: {len(sales_trusted.columns)}
  • Nulos: {sales_trusted.isnull().sum().sum()}
  • Total price validado: {(sales_trusted['quantity'] * sales_trusted['unit_price']).round(2).equals(sales_trusted['total_price'].round(2))}
""")
# Out:
# ================================================================================
# RELATÓRIO FINAL - PHASE 2
# ================================================================================
#
# RESUMO DAS TRANSFORMAÇÕES:
#
# Products:
#   • Registros: 10,000
#   • Campos: 17
#   • Nulos: 0
#   • Margens corrigidas: 359
#   • Descrições técnicas: Adicionadas
#
# Customers:
#   • Registros: 5,000
#   • Campos: 15
#   • Nulos: 0
#   • Mapeamento de problemas por indústria: Adicionado
#
# Sales:
#   • Registros: 120,000
#   • Campos: 15
#   • Nulos: 0
#   • Total price validado: True
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
